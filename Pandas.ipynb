# %%
import pandas as pd

# %%
df = pd.read_csv("adult.data")
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
df.head(10)
# Out:
#    39          State-gov   77516      Bachelors   13           Never-married  \
# 0  50   Self-emp-not-inc   83311      Bachelors   13      Married-civ-spouse
# 1  38            Private  215646        HS-grad    9                Divorced
# 2  53            Private  234721           11th    7      Married-civ-spouse
# 3  28            Private  338409      Bachelors   13      Married-civ-spouse
# 4  37            Private  284582        Masters   14      Married-civ-spouse
# 5  49            Private  160187            9th    5   Married-spouse-absent
# 6  52   Self-emp-not-inc  209642        HS-grad    9      Married-civ-spouse
# 7  31            Private   45781        Masters   14           Never-married
# 8  42            Private  159449      Bachelors   13      Married-civ-spouse
# 9  37            Private  280464   Some-college   10      Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
col_names = [
    'age', 'workclass', 'fnlwgt', 'education', 'education_num',
    'marital_status', 'occupation', 'relationship', 'race', 'sex',
    'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income'
]

# %%
df = pd.read_csv('adult.data', names = col_names , skipinitialspace = True)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
df.describe(include='object')
# Out:
#        workclass education      marital_status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native_country income
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
df.replace('?', pd.NA, inplace=True)

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.isnull().sum()
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.rename(columns={"hours_per_week": "hours"}, inplace=True)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours native_country income
# 0          2174             0     40  United-States  <=50K
# 1             0             0     13  United-States  <=50K
# ...

# %%
df.sample(10)
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 233     33    Private  110978  Some-college             10
# 19596   40    Private  164647  Some-college             10
# 3740    46  State-gov  222374       HS-grad              9
# 26575   45    Private  104521  Some-college             10
# 1575    52    Private  208137     Assoc-voc             11
# 32417   20    Private  227778  Some-college             10
# 27900   42  State-gov   24264  Some-college             10
# 27255   37  State-gov  117651     Bachelors             13
# 25358   32    Private  176998     Bachelors             13
# 18477   30    Private  109282  Some-college             10
#
#            marital_status        occupation    relationship   race     sex  \
# 233              Divorced      Craft-repair  Other-relative  Other  Female
# 19596            Divorced    Prof-specialty       Unmarried  Black  Female
# 3740   Married-civ-spouse     Other-service         Husband  White    Male
# ...

# %%
df.sample(frac=0.3)
# Out:
#        age     workclass  fnlwgt     education  education_num  \
# 32466   37       Private  121521   Prof-school             15
# 10689   25       Private  135568           9th              5
# 3340    24       Private  215443       HS-grad              9
# 21271   50       Private  107265       HS-grad              9
# 27322   38       Private  184801     Bachelors             13
# ...    ...           ...     ...           ...            ...
# 5519    19       Private  227491       HS-grad              9
# 11357   24       Private  179423       HS-grad              9
# 10203   55  Self-emp-inc  124137  Some-college             10
# 5035    55       Private   84774       HS-grad              9
# 32290   31       Private   47151       HS-grad              9
#
#            marital_status         occupation   relationship  \
# 32466  Married-civ-spouse     Prof-specialty        Husband
# 10689  Married-civ-spouse  Handlers-cleaners        Husband
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours              int64
# native_country    object
# income            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30139 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30139 non-null  int64
#  1   workclass       30139 non-null  object
#  2   fnlwgt          30139 non-null  int64
#  3   education       30139 non-null  object
#  4   education_num   30139 non-null  int64
#  5   marital_status  30139 non-null  object
#  6   occupation      30139 non-null  object
#  7   relationship    30139 non-null  object
#  8   race            30139 non-null  object
#  9   sex             30139 non-null  object
#  10  capital_gain    30139 non-null  int64
#  11  capital_loss    30139 non-null  int64
#  12  hours           30139 non-null  int64
#  13  native_country  30139 non-null  object
#  14  income          30139 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df['age']
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 30139, dtype: int64

# %%
df[['age','fnlwgt']]
# Out:
#        age  fnlwgt
# 0       39   77516
# 1       50   83311
# 2       38  215646
# 3       53  234721
# 4       28  338409
# ...    ...     ...
# 32556   27  257302
# 32557   40  154374
# 32558   58  151910
# 32559   22  201490
# 32560   52  287927
#
# [30139 rows x 2 columns]

# %%
df['age'] = df['age'] * 12
df[['age']].head()
# Out:
#    age
# 0  468
# 1  600
# 2  456
# 3  636
# 4  336

# %%
df['age_in_months'] = df['age'] / 12
df[['age_in_months']].head()
# Out:
#    age_in_months
# 0           39.0
# 1           50.0
# 2           38.0
# 3           53.0
# 4           28.0

# %%
df['hours-per-week'] = 100

# %%
df['hours-per-week'] = df['hours-per-week'] - df['age']

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0      468         State-gov   77516   Bachelors             13
# 1      600  Self-emp-not-inc   83311   Bachelors             13
# 2      456           Private  215646     HS-grad              9
# 3      636           Private  234721        11th              7
# 4      336           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556  324           Private  257302  Assoc-acdm             12
# 32557  480           Private  154374     HS-grad              9
# 32558  696           Private  151910     HS-grad              9
# 32559  264           Private  201490     HS-grad              9
# 32560  624      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df = df.drop('age_in_months',axis = 1)
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours', 'native_country', 'income',
#        'hours-per-week'],
#       dtype='object')

# %% [markdown]
# # Access Rows

# %%
df.iloc[0]
# Out:
# age                         468
# workclass             State-gov
# fnlwgt                    77516
# education             Bachelors
# education_num                13
# marital_status    Never-married
# occupation         Adm-clerical
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital_gain               2174
# capital_loss                  0
# hours                        40
# native_country    United-States
# income                    <=50K
# hours-per-week             -368
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# age                         468
# workclass             State-gov
# fnlwgt                    77516
# education             Bachelors
# education_num                13
# marital_status    Never-married
# occupation         Adm-clerical
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital_gain               2174
# capital_loss                  0
# hours                        40
# native_country    United-States
# income                    <=50K
# hours-per-week             -368
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0  468         State-gov   77516  Bachelors             13
# 1  600  Self-emp-not-inc   83311  Bachelors             13
# 2  456           Private  215646    HS-grad              9
# 3  636           Private  234721       11th              7
# 4  336           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours native_country income  hours-per-week
# 0          2174             0     40  United-States  <=50K            -368
# ...

# %%
df.loc[0:5]
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0  468         State-gov   77516  Bachelors             13
# 1  600  Self-emp-not-inc   83311  Bachelors             13
# 2  456           Private  215646    HS-grad              9
# 3  636           Private  234721       11th              7
# 4  336           Private  338409  Bachelors             13
# 5  444           Private  284582    Masters             14
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 5  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
# ...

# %%
df.iloc[0:5, 0:4]
# Out:
#    age         workclass  fnlwgt  education
# 0  468         State-gov   77516  Bachelors
# 1  600  Self-emp-not-inc   83311  Bachelors
# 2  456           Private  215646    HS-grad
# 3  636           Private  234721       11th
# 4  336           Private  338409  Bachelors

# %%
df.count()
# Out:
# age               30139
# workclass         30139
# fnlwgt            30139
# education         30139
# education_num     30139
# marital_status    30139
# occupation        30139
# relationship      30139
# race              30139
# sex               30139
# capital_gain      30139
# capital_loss      30139
# hours             30139
# native_country    30139
# income            30139
# hours-per-week    30139
# dtype: int64

# %%
df["workclass"].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Self-emp-inc', 'Without-pay'], dtype=object)

# %%
df["workclass"].nunique()
# Out:
# 7

# %%
df["education"].value_counts()
# Out:
# HS-grad         9834
# Some-college    6669
# Bachelors       5042
# Masters         1626
# Assoc-voc       1307
# 11th            1048
# Assoc-acdm      1008
# 10th             820
# 7th-8th          556
# Prof-school      542
# 9th              455
# 12th             377
# Doctorate        375
# 5th-6th          287
# 1st-4th          149
# Preschool         44
# Name: education, dtype: int64

# %%
df["workclass"].value_counts()
# Out:
# Private             22264
# Self-emp-not-inc     2498
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Without-pay            14
# Name: workclass, dtype: int64

# %%
df.value_counts()
# Out:
# age   workclass         fnlwgt  education     education_num  marital_status         occupation       relationship   race                sex     capital_gain  capital_loss  hours  native_country  income  hours-per-week
# 204   Federal-gov       99893   11th          7              Never-married          Adm-clerical     Not-in-family  Black               Female  0             1602          40     United-States   <=50K   -104              1
# 528   Local-gov         433705  HS-grad       9              Married-civ-spouse     Protective-serv  Husband        White               Male    0             0             52     United-States   >50K    -428              1
#       Private           36271   Bachelors     13             Married-civ-spouse     Craft-repair     Husband        White               Male    0             0             40     United-States   <=50K   -428              1
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0      468         State-gov   77516   Bachelors             13
# 1      600  Self-emp-not-inc   83311   Bachelors             13
# 2      456           Private  215646     HS-grad              9
# 3      636           Private  234721        11th              7
# 4      336           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556  324           Private  257302  Assoc-acdm             12
# 32557  480           Private  154374     HS-grad              9
# 32558  696           Private  151910     HS-grad              9
# 32559  264           Private  201490     HS-grad              9
# 32560  624      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.value_counts()
# Out:
# age   workclass         fnlwgt  education     education_num  marital_status         occupation       relationship   race                sex     capital_gain  capital_loss  hours  native_country  income  hours-per-week
# 204   Federal-gov       99893   11th          7              Never-married          Adm-clerical     Not-in-family  Black               Female  0             1602          40     United-States   <=50K   -104              1
# 528   Local-gov         433705  HS-grad       9              Married-civ-spouse     Protective-serv  Husband        White               Male    0             0             52     United-States   >50K    -428              1
#       Private           36271   Bachelors     13             Married-civ-spouse     Craft-repair     Husband        White               Male    0             0             40     United-States   <=50K   -428              1
# ...

# %%
df["native_country"].value_counts(normalize = True)*100
# Out:
# United-States                 91.200770
# Mexico                         2.010684
# Philippines                    0.623777
# Germany                        0.424699
# Puerto-Rico                    0.361658
# Canada                         0.355022
# India                          0.331796
# El-Salvador                    0.331796
# Cuba                           0.305252
# England                        0.285345
# Jamaica                        0.265437
# South                          0.235575
# China                          0.225621
# Italy                          0.225621
# Dominican-Republic             0.222303
# Vietnam                        0.212349
# Guatemala                      0.202396
# Japan                          0.195760
# Poland                         0.185806
# Columbia                       0.185806
# Iran                           0.139354
# Taiwan                         0.139354
# Haiti                          0.139354
# ...

# %%
df["education"].value_counts(normalize = True)*100
# Out:
# HS-grad         32.628820
# Some-college    22.127476
# Bachelors       16.729155
# Masters          5.395003
# Assoc-voc        4.336574
# 11th             3.477222
# Assoc-acdm       3.344504
# 10th             2.720727
# 7th-8th          1.844786
# Prof-school      1.798334
# 9th              1.509672
# 12th             1.250871
# Doctorate        1.244235
# 5th-6th          0.952255
# 1st-4th          0.494376
# Preschool        0.145990
# Name: education, dtype: float64

# %%
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital_gain  capital_loss  \
# ...

# %%
df.isna()
# Out:
#          age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital_gain  capital_loss  \
# ...

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours             0
# native_country    0
# income            0
# hours-per-week    0
# dtype: int64

# %%
df["age"]>40
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 32556    True
# 32557    True
# 32558    True
# 32559    True
# 32560    True
# Name: age, Length: 30139, dtype: bool

# %%
df[df["education"]== "Bachelors"]
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 0      468         State-gov   77516  Bachelors             13
# 1      600  Self-emp-not-inc   83311  Bachelors             13
# 4      336           Private  338409  Bachelors             13
# 9      504           Private  159449  Bachelors             13
# 11     360         State-gov  141297  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 32507  600           Private  302372  Bachelors             13
# 32511  300         Local-gov  514716  Bachelors             13
# 32533  648           Private  337992  Bachelors             13
# 32536  408           Private  160216  Bachelors             13
# 32538  456           Private  139180  Bachelors             13
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
df[df["age"]>40]
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0      468         State-gov   77516   Bachelors             13
# 1      600  Self-emp-not-inc   83311   Bachelors             13
# 2      456           Private  215646     HS-grad              9
# 3      636           Private  234721        11th              7
# 4      336           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556  324           Private  257302  Assoc-acdm             12
# 32557  480           Private  154374     HS-grad              9
# 32558  696           Private  151910     HS-grad              9
# 32559  264           Private  201490     HS-grad              9
# 32560  624      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df['age'] // 12
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0      468         State-gov   77516   Bachelors             13
# 1      600  Self-emp-not-inc   83311   Bachelors             13
# 2      456           Private  215646     HS-grad              9
# 3      636           Private  234721        11th              7
# 4      336           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556  324           Private  257302  Assoc-acdm             12
# 32557  480           Private  154374     HS-grad              9
# 32558  696           Private  151910     HS-grad              9
# 32559  264           Private  201490     HS-grad              9
# 32560  624      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df['age'] = df['age'] // 12
df['age']
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 30139, dtype: int64

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df[(df['age'] > 40) & (df["hours"] > 40)]
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 19      43  Self-emp-not-inc  292175       Masters             14
# 52      47           Private   51835   Prof-school             15
# 53      50       Federal-gov  251585     Bachelors             13
# 54      47      Self-emp-inc  109832       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32533   54           Private  337992     Bachelors             13
# 32543   45         Local-gov  119199    Assoc-acdm             12
# 32548   65  Self-emp-not-inc   99359   Prof-school             15
# 32550   43  Self-emp-not-inc   27242  Some-college             10
# 32552   43           Private   84661     Assoc-voc             11
#
#            marital_status       occupation   relationship                race  \
# 7      Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %%
df[(df['education']=="Bachelors")| (df["education"]=="Masters")]
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
df[~(df["income"] == "<=50K")]
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32538   38           Private  139180     Bachelors             13
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital_status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
higher_ed = ["Bachelors","Masters","Doctorate","Prof-school"]
df[df["education"].isin(higher_ed)]
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 0       39         State-gov   77516    Bachelors             13
# 1       50  Self-emp-not-inc   83311    Bachelors             13
# 4       28           Private  338409    Bachelors             13
# 5       37           Private  284582      Masters             14
# 8       31           Private   45781      Masters             14
# ...    ...               ...     ...          ...            ...
# 32538   38           Private  139180    Bachelors             13
# 32544   31           Private  199655      Masters             14
# 32548   65  Self-emp-not-inc   99359  Prof-school             15
# 32553   32           Private  116138      Masters             14
# 32554   53           Private  321865      Masters             14
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
df[df["age"].between(30,40)]
# Out:
#        age  workclass  fnlwgt     education  education_num  \
# 0       39  State-gov   77516     Bachelors             13
# 2       38    Private  215646       HS-grad              9
# 5       37    Private  284582       Masters             14
# 8       31    Private   45781       Masters             14
# 10      37    Private  280464  Some-college             10
# ...    ...        ...     ...           ...            ...
# 32545   39  Local-gov  111499    Assoc-acdm             12
# 32546   37    Private  198216    Assoc-acdm             12
# 32551   32    Private   34066          10th              6
# 32553   32    Private  116138       Masters             14
# 32557   40    Private  154374       HS-grad              9
#
#            marital_status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 2                Divorced  Handlers-cleaners  Not-in-family
# 5      Married-civ-spouse    Exec-managerial           Wife
# ...

# %%
df.loc[
    df["income"]== ">50K",
    ["age","education","occupation","hours","income"]
].head()
# Out:
#     age     education       occupation  hours income
# 7    52       HS-grad  Exec-managerial     45   >50K
# 8    31       Masters   Prof-specialty     50   >50K
# 9    42     Bachelors  Exec-managerial     40   >50K
# 10   37  Some-college  Exec-managerial     80   >50K
# 11   30     Bachelors   Prof-specialty     40   >50K

# %%
df.groupby('education')

# %%
df.groupby('education').get_group("Bachelors")
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 32507   50           Private  302372  Bachelors             13
# 32511   25         Local-gov  514716  Bachelors             13
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
#
#            marital_status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
df.groupby('education').get_group("Bachelors").head()
# Out:
#     age         workclass  fnlwgt  education  education_num  \
# 0    39         State-gov   77516  Bachelors             13
# 1    50  Self-emp-not-inc   83311  Bachelors             13
# 4    28           Private  338409  Bachelors             13
# 9    42           Private  159449  Bachelors             13
# 11   30         State-gov  141297  Bachelors             13
#
#         marital_status       occupation   relationship                race  \
# 0        Never-married     Adm-clerical  Not-in-family               White
# 1   Married-civ-spouse  Exec-managerial        Husband               White
# 4   Married-civ-spouse   Prof-specialty           Wife               Black
# 9   Married-civ-spouse  Exec-managerial        Husband               White
# 11  Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
#
#        sex  capital_gain  capital_loss  hours native_country income  \
# 0     Male          2174             0     40  United-States  <=50K
# ...

# %%
df.groupby("income")["age"].mean()
# Out:
# income
# <=50K    36.611585
# >50K     43.960165
# Name: age, dtype: float64

# %%
df.groupby("income")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_29240\3880542178.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("income").sum()
#            age      fnlwgt  education_num  capital_gain  capital_loss   hours  \
# income
# <=50K   828630  4308013809         217961       3373041       1210811  890654
# >50K    329965  1412218479          87122      29564100       1454680  343077
#
#         hours-per-week
# income
# <=50K         -7680260
# >50K          -3208980

# %%
df['age'].agg(['mean','median','sum'])
# Out:
# mean      3.844172e+01
# median    3.700000e+01
# sum       1.158595e+06
# Name: age, dtype: float64

# %%
df['age']= df['age'].astype("int64")

# %%
df['age'].agg(['mean','median','sum'])
# Out:
# mean      3.844172e+01
# median    3.700000e+01
# sum       1.158595e+06
# Name: age, dtype: float64

# %%
df.groupby("income")[['age','hours','education_num']].agg(['mean','std'])
# Out:
#               age                 hours            education_num
#              mean        std       mean        std          mean       std
# income
# <=50K   36.611585  13.460776  39.352008  11.949217      9.630230  2.411865
# >50K    43.960165  10.270746  45.707034  10.738183     11.606981  2.368475

# %%
df.groupby(['income','sex']){'hours'}
